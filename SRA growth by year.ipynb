# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_sra=pd.read_csv('sra_complete_runs.csv',low_memory=False)
df_sra.head()
# Out:
#           Run          ReleaseDate LoadDate  spots  bases  spots_with_mates  \
# 0  ERR3550121  2019-09-25 19:35:40      NaN      0      0                 0
# 1  ERR3550142  2019-09-25 19:35:41      NaN      0      0                 0
# 2  ERR3550147  2019-09-25 19:35:41      NaN      0      0                 0
# 3  ERR3550125  2019-09-25 19:35:40      NaN      0      0                 0
# 4  ERR3550137  2019-09-25 19:35:40      NaN      0      0                 0
#
#    avgLength  size_MB AssemblyName download_path  ... Affection_Status  \
# 0          0        0          NaN           NaN  ...              NaN
# 1          0        0          NaN           NaN  ...              NaN
# 2          0        0          NaN           NaN  ...              NaN
# 3          0        0          NaN           NaN  ...              NaN
# 4          0        0          NaN           NaN  ...              NaN
#
#   Analyte_Type Histological_Type Body_Site CenterName  Submission  \
# 0          NaN               NaN       NaN    UOC-CCG  ERA2143351
# 1          NaN               NaN       NaN    UOC-CCG  ERA2143351
# 2          NaN               NaN       NaN    UOC-CCG  ERA2143351
# 3          NaN               NaN       NaN    UOC-CCG  ERA2143351
# 4          NaN               NaN       NaN    UOC-CCG  ERA2143351
#
#    dbgap_study_accession  Consent RunHash ReadHash
# 0                    NaN   public     NaN      NaN
# 1                    NaN   public     NaN      NaN
# 2                    NaN   public     NaN      NaN
# 3                    NaN   public     NaN      NaN
# 4                    NaN   public     NaN      NaN
#
# [5 rows x 47 columns]

# %%
df_sra['ReleaseDate'] = df_sra['ReleaseDate'].apply(lambda x : pd.to_datetime(str(x)))
df_sra['year'] = df_sra['ReleaseDate'].dt.year

# %%
df_sra_dates = df_sra.groupby('year').year.count()
print(df_sra_dates)
# Out:
# year
# 2007.0        234
# 2008.0       5973
# 2009.0      17934
# 2010.0      54034
# 2011.0      73056
# 2012.0     153524
# 2013.0     214856
# 2014.0     456205
# 2015.0     719732
# 2016.0    1153013
# 2017.0    1264957
# 2018.0    2030461
# 2019.0    1531883
# Name: year, dtype: int64

# %%
plt.style.use('seaborn-whitegrid')
sns.set_context(font_scale=3, rc={"lines.linewidth": 10})
plt.figure(figsize=(30,15))

ax = sns.lineplot(data = df_sra_dates)
ax.set_xlabel("Year", fontsize=45)
ax.set_ylabel("Number of SRA runs", fontsize=45)
plt.yscale('log')

ax.grid(False)
sns.despine()
plt.tick_params(labelsize=40)
