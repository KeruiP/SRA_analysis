# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_sra_10k=pd.read_csv("test_sra_10k.csv",low_memory=False)

# %%
ax=sns.countplot(x='LibraryStrategy',data=df_sra_10k)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha="right")
plt.tight_layout()
plt.show()
